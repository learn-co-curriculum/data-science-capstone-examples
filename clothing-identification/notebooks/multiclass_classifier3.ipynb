# %% [markdown]
# <a href="https://colab.research.google.com/github/FarnazG/dsc-capstone-project-v2-online-ds-ft-120919/blob/master/multiclass_classifier3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  **Modeling:**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras import losses

import numpy as np #for numerical computations
import pandas as pd #for dataframe operations

from matplotlib import pyplot as plt #for viewing images and plots
# %matplotlib inline 
#So that Matplotlib plots don't open in separate windows outside the notebook

import urllib #For fetching data from Web URLs

import cv2   #For image processing

from sklearn.preprocessing import LabelEncoder    #For encoding categorical variables
from sklearn.model_selection import train_test_split #For splitting of dataset

#All tensorflow utilities for creating, training and working with a CNN
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, BatchNormalization
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # **After 'X' is downloaded:**

# %%
# some URL images that were not readable were deleted:
X3 = np.load('/content/drive/My Drive/Capstone Project/X_gray_df2598.npy') 
X2 = np.load('/content/drive/My Drive/Capstone Project/X_gray_df2000.npy') 
X1 = np.load('/content/drive/My Drive/Capstone Project/X_gray_df1000.npy') 
X = np.concatenate((X1, X2, X3))
print(X.shape)

#gray image size grayscale 1 color
img_size=(400,300)

#colored image size RGB 3 Colors
#img_size=(400,300,3)
# Out:
# (2598, 120000)

# %% [markdown]
# To see how well the image processing works , we will fetch 5 samples from 'X' at random and plot them:

# %%
#Select 5 processed images at random from 'X' and plot 
for i in range(0, 1):
  plt.figure()
  plt.imshow(X[i].reshape(img_size), cmap='gray'), plt.axis('off')

# %% [markdown]
# **Splitting the data:**
#
# We need to split the data into training, validation, and test sets.
#
# **Creating the Target Array:**
#
# We already have our 'X'. Now, we need our 'Y'.
#
# We will ceate it from the 'Price' column of our dataframe.
#
# if we use brand name column as 'y', It consists of the categorical labels. then We will map each label with a number using the LabelEncoder.

# %%
df= pd.read_csv('/content/drive/My Drive/Capstone Project/df.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ...            shortDescription stockTotal
# 0           0            41  ...   Geranium print mini dress         38
# 1           1            57  ...       Stirrups print blouse         13
# 2           2           122  ...    Zebra print peplum skirt          4
# 3           3           128  ...    Lily print flounce dress         18
# 4           4            96  ...   graffiti art print jacket          1
#
# [5 rows x 20 columns]

# %%
n_classes = df['brand.name'].nunique()
print('Total number of unique categories:', n_classes)
# Out:
# Total number of unique categories: 5

# %%
encoder = LabelEncoder()
Targets = encoder.fit_transform(df['brand.name'])
Targets
Targets.shape
# Out:
# (2598,)

# %%
Y = to_categorical(Targets, num_classes = n_classes)
#Y[0:3]
Y.shape
# Out:
# (2598, 5)

# %% [markdown]
# **Separation of a validation set, and a test set:**

# %%
# we consider 80% of our data as training and 20% as testing:
X_test = X[2000:,]
Y_test = Y[2000:,]

#Seperation of a validation set 15% from the remaing training set (required for validation while training)

X_train, X_val, Y_train, Y_val = train_test_split(X[:2000,], Y[:2000,], test_size=0.15, random_state=13)

# %% [markdown]
# **Reshaping the input data**
#
# we already reshaped out images earlier into 360000x1 row arrays, since it was easier to store them that way. But CNN requires input data in form of nice multi-dimensional grids. For our colored image data, the third dimesion will be 3 and for gray-scale is 1.

# %%
#Reshape the input matrices such that each sample is three-dimensional, in gray scale the last number is 1 and in colored images its 3
#normalizing images between 0 and 1 while splitting the data: X = X/255

img_rows, img_cols = 400, 300
input_shape = (img_rows, img_cols, 1)

X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols, 1)
X_train = X_train/255
X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, 1)
X_test = X_test/255
X_val = X_val.reshape(X_val.shape[0], img_rows, img_cols, 1)
X_val = X_val/255

X_val.shape
# Out:
# (300, 400, 300, 1)

# %% [markdown]
# # **Convolutional Neural Network**
#
# Compiling the model

# %%
#Define a Convolutional Neural Network Model
#changing model architecture and also the activation function from tanh to sigmoid

model = Sequential()

model.add(Conv2D(filters = 16, kernel_size = (3, 3), activation='sigmoid', input_shape = input_shape))
#model.add(BatchNormalization())
#model.add(Conv2D(filters = 16, kernel_size = (3, 3), activation='tanh'))
#model.add(BatchNormalization())
model.add(MaxPool2D(strides=(2,2)))
model.add(Dropout(0.25))

# model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation='relu'))
# model.add(BatchNormalization())
model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation='sigmoid'))
model.add(BatchNormalization())
# model.add(MaxPool2D(strides=(2,2)))
# model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.25))

model.add(Dense(1024, activation='sigmoid'))
model.add(Dropout(0.4))
model.add(Dense(n_classes, activation='softmax'))

learning_rate = 0.001

model.compile(loss = categorical_crossentropy,
              optimizer = Adam(learning_rate),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 398, 298, 16)      160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 199, 149, 16)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 199, 149, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 197, 147, 32)      4640
# _________________________________________________________________
# batch_normalization (BatchNo (None, 197, 147, 32)      128
# _________________________________________________________________
# flatten (Flatten)            (None, 926688)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               474464768
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 475,000,133
# Trainable params: 475,000,069
# Non-trainable params: 64
# _________________________________________________________________

# %%
#Save the model during training 

save_at = "/content/drive/My Drive/Capstone Project/model.hdf5"
save_best = ModelCheckpoint (save_at, monitor='val_accuracy', verbose=0, save_best_only=True, save_weights_only=False, mode='max')

# %%
#Train the CNN

history = model.fit( X_train, Y_train, 
                    epochs = 100, batch_size = 20, 
                    callbacks=[save_best], verbose=1, 
                    validation_data = (X_val, Y_val))

# Plot the training history (Training accuracy & Validation accuracy)

plt.figure(figsize=(6, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy', weight='bold', fontsize=16)
plt.ylabel('accuracy', weight='bold', fontsize=14)
plt.xlabel('epoch', weight='bold', fontsize=14)
plt.ylim(0.1, 0.9)
plt.xticks(weight='bold', fontsize=12)
plt.yticks(weight='bold', fontsize=12)
plt.legend(['train', 'val'], loc='upper left', prop={'size': 14})
plt.grid(color = 'y', linewidth='0.5')
plt.show()
# Out:
# Epoch 1/100
# 85/85 [==============================] - 401s 5s/step - loss: 1.7509 - accuracy: 0.2682 - val_loss: 1.7962 - val_accuracy: 0.2433
# Epoch 2/100
# 85/85 [==============================] - 257s 3s/step - loss: 1.6261 - accuracy: 0.3053 - val_loss: 1.6128 - val_accuracy: 0.2433
# Epoch 3/100
# 85/85 [==============================] - 235s 3s/step - loss: 1.5775 - accuracy: 0.3035 - val_loss: 1.7060 - val_accuracy: 0.2400
# Epoch 4/100
# 85/85 [==============================] - 413s 5s/step - loss: 1.5355 - accuracy: 0.3159 - val_loss: 1.6755 - val_accuracy: 0.2533
# Epoch 5/100
# 85/85 [==============================] - 254s 3s/step - loss: 1.5014 - accuracy: 0.3276 - val_loss: 1.7708 - val_accuracy: 0.2433
# Epoch 6/100
# 85/85 [==============================] - 244s 3s/step - loss: 1.4917 - accuracy: 0.3576 - val_loss: 1.6947 - val_accuracy: 0.2067
# Epoch 7/100
# 85/85 [==============================] - 419s 5s/step - loss: 1.4838 - accuracy: 0.3294 - val_loss: 1.5248 - val_accuracy: 0.3133
# Epoch 8/100
# 85/85 [==============================] - 263s 3s/step - loss: 1.4713 - accuracy: 0.3518 - val_loss: 1.5500 - val_accuracy: 0.3000
# Epoch 9/100
# 85/85 [==============================] - 238s 3s/step - loss: 1.4759 - accuracy: 0.3394 - val_loss: 1.6228 - val_accuracy: 0.2600
# Epoch 10/100
# 85/85 [==============================] - 241s 3s/step - loss: 1.4791 - accuracy: 0.3488 - val_loss: 1.6668 - val_accuracy: 0.2433
# Epoch 11/100
# 85/85 [==============================] - 237s 3s/step - loss: 1.4702 - accuracy: 0.3324 - val_loss: 1.6583 - val_accuracy: 0.2733
# Epoch 12/100
# 85/85 [==============================] - 238s 3s/step - loss: 1.4534 - accuracy: 0.3535 - val_loss: 1.7298 - val_accuracy: 0.2433
# Epoch 13/100
# 85/85 [==============================] - 240s 3s/step - loss: 1.4686 - accuracy: 0.3447 - val_loss: 1.6116 - val_accuracy: 0.2467
# Epoch 14/100
# 85/85 [==============================] - 239s 3s/step - loss: 1.4613 - accuracy: 0.3465 - val_loss: 1.6959 - val_accuracy: 0.2667
# Epoch 15/100
# 85/85 [==============================] - 237s 3s/step - loss: 1.4567 - accuracy: 0.3735 - val_loss: 1.5939 - val_accuracy: 0.2567
# Epoch 16/100
# 85/85 [==============================] - 407s 5s/step - loss: 1.4643 - accuracy: 0.3641 - val_loss: 1.4948 - val_accuracy: 0.3467
# Epoch 17/100
# 85/85 [==============================] - 263s 3s/step - loss: 1.4548 - accuracy: 0.3600 - val_loss: 1.7313 - val_accuracy: 0.1767
# Epoch 18/100
# 85/85 [==============================] - 239s 3s/step - loss: 1.4584 - accuracy: 0.3653 - val_loss: 1.5029 - val_accuracy: 0.3400
# Epoch 19/100
# 85/85 [==============================] - 239s 3s/step - loss: 1.4573 - accuracy: 0.3659 - val_loss: 1.6477 - val_accuracy: 0.2733
# Epoch 20/100
# 85/85 [==============================] - 243s 3s/step - loss: 1.4487 - accuracy: 0.3688 - val_loss: 1.5525 - val_accuracy: 0.3000
# Epoch 21/100
# 85/85 [==============================] - 238s 3s/step - loss: 1.4552 - accuracy: 0.3665 - val_loss: 1.5199 - val_accuracy: 0.2867
# Epoch 22/100
# 85/85 [==============================] - 238s 3s/step - loss: 1.4666 - accuracy: 0.3471 - val_loss: 1.6357 - val_accuracy: 0.2433
# Epoch 23/100
# 85/85 [==============================] - 238s 3s/step - loss: 1.4625 - accuracy: 0.3576 - val_loss: 1.5231 - val_accuracy: 0.3300
# Epoch 24/100
# 85/85 [==============================] - 239s 3s/step - loss: 1.4518 - accuracy: 0.3618 - val_loss: 1.6405 - val_accuracy: 0.2667
# Epoch 25/100
# 85/85 [==============================] - 240s 3s/step - loss: 1.4501 - accuracy: 0.3706 - val_loss: 1.6821 - val_accuracy: 0.2667
# Epoch 26/100
# 85/85 [==============================] - 238s 3s/step - loss: 1.4555 - accuracy: 0.3471 - val_loss: 1.5525 - val_accuracy: 0.2967
# Epoch 27/100
# 85/85 [==============================] - 243s 3s/step - loss: 1.4552 - accuracy: 0.3600 - val_loss: 1.7129 - val_accuracy: 0.2467
# Epoch 28/100
# 85/85 [==============================] - 240s 3s/step - loss: 1.4504 - accuracy: 0.3588 - val_loss: 1.6164 - val_accuracy: 0.2567
# Epoch 29/100
# 85/85 [==============================] - 239s 3s/step - loss: 1.4340 - accuracy: 0.3724 - val_loss: 1.5341 - val_accuracy: 0.3233
# Epoch 30/100
# 85/85 [==============================] - 239s 3s/step - loss: 1.4427 - accuracy: 0.3594 - val_loss: 1.5863 - val_accuracy: 0.2867
# Epoch 31/100
# 85/85 [==============================] - 235s 3s/step - loss: 1.4453 - accuracy: 0.3682 - val_loss: 1.6811 - val_accuracy: 0.2600
# Epoch 32/100
# 85/85 [==============================] - 237s 3s/step - loss: 1.4425 - accuracy: 0.3747 - val_loss: 1.5775 - val_accuracy: 0.3067
# Epoch 33/100
# 85/85 [==============================] - 237s 3s/step - loss: 1.4631 - accuracy: 0.3600 - val_loss: 1.5835 - val_accuracy: 0.3267
# Epoch 34/100
# 85/85 [==============================] - 235s 3s/step - loss: 1.4558 - accuracy: 0.3724 - val_loss: 1.6882 - val_accuracy: 0.2700
# Epoch 35/100
# 85/85 [==============================] - 237s 3s/step - loss: 1.4623 - accuracy: 0.3741 - val_loss: 1.5187 - val_accuracy: 0.3333
# Epoch 36/100
# 85/85 [==============================] - 235s 3s/step - loss: 1.4623 - accuracy: 0.3435 - val_loss: 1.5281 - val_accuracy: 0.2833
# Epoch 37/100
# 85/85 [==============================] - 404s 5s/step - loss: 1.4552 - accuracy: 0.3606 - val_loss: 1.4955 - val_accuracy: 0.3633
# Epoch 38/100
# 85/85 [==============================] - 257s 3s/step - loss: 1.4473 - accuracy: 0.3588 - val_loss: 1.5514 - val_accuracy: 0.3133
# Epoch 39/100
# 85/85 [==============================] - 242s 3s/step - loss: 1.4458 - accuracy: 0.3635 - val_loss: 1.5414 - val_accuracy: 0.3333
# Epoch 40/100
# 85/85 [==============================] - 239s 3s/step - loss: 1.4456 - accuracy: 0.3718 - val_loss: 1.5784 - val_accuracy: 0.2967
# Epoch 41/100
# 85/85 [==============================] - 241s 3s/step - loss: 1.4467 - accuracy: 0.3712 - val_loss: 1.4921 - val_accuracy: 0.3533
# Epoch 42/100
# 85/85 [==============================] - 240s 3s/step - loss: 1.4537 - accuracy: 0.3612 - val_loss: 1.5224 - val_accuracy: 0.3500
# Epoch 43/100
# 85/85 [==============================] - 238s 3s/step - loss: 1.4560 - accuracy: 0.3624 - val_loss: 1.5008 - val_accuracy: 0.3600
# Epoch 44/100
# 85/85 [==============================] - 241s 3s/step - loss: 1.4522 - accuracy: 0.3765 - val_loss: 1.5826 - val_accuracy: 0.3000
# Epoch 45/100
# 85/85 [==============================] - 236s 3s/step - loss: 1.4526 - accuracy: 0.3624 - val_loss: 1.5862 - val_accuracy: 0.2967
# Epoch 46/100
# 85/85 [==============================] - 235s 3s/step - loss: 1.4502 - accuracy: 0.3671 - val_loss: 1.5967 - val_accuracy: 0.2733
# Epoch 47/100
# 85/85 [==============================] - 237s 3s/step - loss: 1.4530 - accuracy: 0.3706 - val_loss: 1.6059 - val_accuracy: 0.2600
# Epoch 48/100
# 85/85 [==============================] - 235s 3s/step - loss: 1.4403 - accuracy: 0.3771 - val_loss: 1.5672 - val_accuracy: 0.2867
# Epoch 49/100
# 85/85 [==============================] - 235s 3s/step - loss: 1.4451 - accuracy: 0.3765 - val_loss: 1.4924 - val_accuracy: 0.3533
# Epoch 50/100
# 85/85 [==============================] - 236s 3s/step - loss: 1.4433 - accuracy: 0.3788 - val_loss: 1.4792 - val_accuracy: 0.3367
# Epoch 51/100
# 85/85 [==============================] - 239s 3s/step - loss: 1.4410 - accuracy: 0.3718 - val_loss: 1.5767 - val_accuracy: 0.3000
# Epoch 52/100
# 85/85 [==============================] - 237s 3s/step - loss: 1.4530 - accuracy: 0.3753 - val_loss: 1.4748 - val_accuracy: 0.3367
# Epoch 53/100
# 85/85 [==============================] - 237s 3s/step - loss: 1.4513 - accuracy: 0.3653 - val_loss: 1.5435 - val_accuracy: 0.3333
# Epoch 54/100
# 85/85 [==============================] - 234s 3s/step - loss: 1.4406 - accuracy: 0.3724 - val_loss: 1.4638 - val_accuracy: 0.3533
# Epoch 55/100
# 85/85 [==============================] - 233s 3s/step - loss: 1.4439 - accuracy: 0.3735 - val_loss: 1.5206 - val_accuracy: 0.3300
# Epoch 56/100
# 85/85 [==============================] - 231s 3s/step - loss: 1.4574 - accuracy: 0.3606 - val_loss: 1.6427 - val_accuracy: 0.2400
# Epoch 57/100
# 85/85 [==============================] - 231s 3s/step - loss: 1.4525 - accuracy: 0.3759 - val_loss: 1.6467 - val_accuracy: 0.2233
# Epoch 58/100
# 85/85 [==============================] - 230s 3s/step - loss: 1.4520 - accuracy: 0.3635 - val_loss: 1.4991 - val_accuracy: 0.3233
# Epoch 59/100
# 85/85 [==============================] - 230s 3s/step - loss: 1.4574 - accuracy: 0.3588 - val_loss: 1.5383 - val_accuracy: 0.3033
# Epoch 60/100
# 85/85 [==============================] - 231s 3s/step - loss: 1.4486 - accuracy: 0.3729 - val_loss: 1.4777 - val_accuracy: 0.3533
# Epoch 61/100
# 85/85 [==============================] - 227s 3s/step - loss: 1.4360 - accuracy: 0.3682 - val_loss: 1.5223 - val_accuracy: 0.3133
# Epoch 62/100
# 85/85 [==============================] - 230s 3s/step - loss: 1.4367 - accuracy: 0.3788 - val_loss: 1.4885 - val_accuracy: 0.3600
# Epoch 63/100
# 85/85 [==============================] - 227s 3s/step - loss: 1.4479 - accuracy: 0.3535 - val_loss: 1.5626 - val_accuracy: 0.2867
# Epoch 64/100
# 85/85 [==============================] - 227s 3s/step - loss: 1.4546 - accuracy: 0.3512 - val_loss: 1.5772 - val_accuracy: 0.2933
# Epoch 65/100
# 85/85 [==============================] - 400s 5s/step - loss: 1.4515 - accuracy: 0.3576 - val_loss: 1.5107 - val_accuracy: 0.3667
# Epoch 66/100
# 85/85 [==============================] - 254s 3s/step - loss: 1.4488 - accuracy: 0.3629 - val_loss: 1.5793 - val_accuracy: 0.2833
# Epoch 67/100
# 85/85 [==============================] - 242s 3s/step - loss: 1.4412 - accuracy: 0.3676 - val_loss: 1.5797 - val_accuracy: 0.2867
# Epoch 68/100
# 85/85 [==============================] - 238s 3s/step - loss: 1.4384 - accuracy: 0.3659 - val_loss: 1.5184 - val_accuracy: 0.3367
# Epoch 69/100
# 85/85 [==============================] - 241s 3s/step - loss: 1.4469 - accuracy: 0.3776 - val_loss: 1.4958 - val_accuracy: 0.3500
# Epoch 70/100
# 85/85 [==============================] - 236s 3s/step - loss: 1.4543 - accuracy: 0.3541 - val_loss: 1.4906 - val_accuracy: 0.3300
# Epoch 71/100
# 85/85 [==============================] - 235s 3s/step - loss: 1.4547 - accuracy: 0.3618 - val_loss: 1.5181 - val_accuracy: 0.3267
# Epoch 72/100
# 85/85 [==============================] - 237s 3s/step - loss: 1.4453 - accuracy: 0.3635 - val_loss: 1.5410 - val_accuracy: 0.3133
# Epoch 73/100
# 85/85 [==============================] - 235s 3s/step - loss: 1.4463 - accuracy: 0.3665 - val_loss: 1.7064 - val_accuracy: 0.2433
# Epoch 74/100
# 85/85 [==============================] - 234s 3s/step - loss: 1.4461 - accuracy: 0.3771 - val_loss: 1.5557 - val_accuracy: 0.3267
# Epoch 75/100
# 85/85 [==============================] - 235s 3s/step - loss: 1.4600 - accuracy: 0.3547 - val_loss: 1.4984 - val_accuracy: 0.3167
# Epoch 76/100
# 85/85 [==============================] - 234s 3s/step - loss: 1.4534 - accuracy: 0.3700 - val_loss: 1.5032 - val_accuracy: 0.3467
# Epoch 77/100
# 85/85 [==============================] - 234s 3s/step - loss: 1.4450 - accuracy: 0.3682 - val_loss: 1.5188 - val_accuracy: 0.3400
# Epoch 78/100
# 85/85 [==============================] - 235s 3s/step - loss: 1.4488 - accuracy: 0.3641 - val_loss: 1.4890 - val_accuracy: 0.3500
# Epoch 79/100
# 85/85 [==============================] - 234s 3s/step - loss: 1.4419 - accuracy: 0.3618 - val_loss: 1.7121 - val_accuracy: 0.2467
# Epoch 80/100
# 85/85 [==============================] - 235s 3s/step - loss: 1.4626 - accuracy: 0.3482 - val_loss: 1.6406 - val_accuracy: 0.2433
# Epoch 81/100
# 85/85 [==============================] - 235s 3s/step - loss: 1.4428 - accuracy: 0.3718 - val_loss: 1.5865 - val_accuracy: 0.2733
# Epoch 82/100
# 85/85 [==============================] - 237s 3s/step - loss: 1.4424 - accuracy: 0.3624 - val_loss: 1.5101 - val_accuracy: 0.3200
# Epoch 83/100
# 85/85 [==============================] - 236s 3s/step - loss: 1.4544 - accuracy: 0.3582 - val_loss: 1.7124 - val_accuracy: 0.2333
# Epoch 84/100
# 85/85 [==============================] - 235s 3s/step - loss: 1.4484 - accuracy: 0.3529 - val_loss: 1.5902 - val_accuracy: 0.2533
# Epoch 85/100
# 85/85 [==============================] - 236s 3s/step - loss: 1.4367 - accuracy: 0.3706 - val_loss: 1.5354 - val_accuracy: 0.3133
# Epoch 86/100
# 85/85 [==============================] - 235s 3s/step - loss: 1.4498 - accuracy: 0.3618 - val_loss: 1.5705 - val_accuracy: 0.2800
# Epoch 87/100
# 85/85 [==============================] - 238s 3s/step - loss: 1.4475 - accuracy: 0.3641 - val_loss: 1.6648 - val_accuracy: 0.2467
# Epoch 88/100
# 85/85 [==============================] - 235s 3s/step - loss: 1.4440 - accuracy: 0.3582 - val_loss: 1.5048 - val_accuracy: 0.3600
# Epoch 89/100
# 85/85 [==============================] - 234s 3s/step - loss: 1.4516 - accuracy: 0.3718 - val_loss: 1.6646 - val_accuracy: 0.2400
# Epoch 90/100
# 85/85 [==============================] - 237s 3s/step - loss: 1.4550 - accuracy: 0.3641 - val_loss: 1.5789 - val_accuracy: 0.2933
# Epoch 91/100
# 85/85 [==============================] - 235s 3s/step - loss: 1.4370 - accuracy: 0.3682 - val_loss: 1.5305 - val_accuracy: 0.3300
# Epoch 92/100
# 85/85 [==============================] - 409s 5s/step - loss: 1.4506 - accuracy: 0.3535 - val_loss: 1.4691 - val_accuracy: 0.3867
# Epoch 93/100
# 85/85 [==============================] - 254s 3s/step - loss: 1.4416 - accuracy: 0.3729 - val_loss: 1.6590 - val_accuracy: 0.2800
# Epoch 94/100
# 85/85 [==============================] - 239s 3s/step - loss: 1.4465 - accuracy: 0.3724 - val_loss: 1.5207 - val_accuracy: 0.3400
# Epoch 95/100
# 85/85 [==============================] - 235s 3s/step - loss: 1.4405 - accuracy: 0.3553 - val_loss: 1.6630 - val_accuracy: 0.2867
# Epoch 96/100
# 85/85 [==============================] - 231s 3s/step - loss: 1.4538 - accuracy: 0.3441 - val_loss: 2.0109 - val_accuracy: 0.2333
# Epoch 97/100
# 85/85 [==============================] - 232s 3s/step - loss: 1.4456 - accuracy: 0.3600 - val_loss: 1.7052 - val_accuracy: 0.2567
# Epoch 98/100
# 85/85 [==============================] - 230s 3s/step - loss: 1.4519 - accuracy: 0.3618 - val_loss: 1.7651 - val_accuracy: 0.2467
# Epoch 99/100
# 85/85 [==============================] - 231s 3s/step - loss: 1.4585 - accuracy: 0.3547 - val_loss: 1.5301 - val_accuracy: 0.3267
# Epoch 100/100
# 85/85 [==============================] - 228s 3s/step - loss: 1.4492 - accuracy: 0.3571 - val_loss: 1.5303 - val_accuracy: 0.3100

# %% [markdown]
# after all changes we have made to the model, the accuracy is still not good enough and it seems that more changes are making the model overfit the training data, so we move to our next approach which is transfer learning to compare the results.
