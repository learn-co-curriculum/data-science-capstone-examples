# %% [markdown]
# <a href="https://colab.research.google.com/github/FarnazG/dsc-capstone-project-v2-online-ds-ft-120919/blob/master/multiclass_classifier1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  **Modeling:**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras import losses

import numpy as np #for numerical computations
import pandas as pd #for dataframe operations

from matplotlib import pyplot as plt #for viewing images and plots
# %matplotlib inline 
#So that Matplotlib plots don't open in separate windows outside the notebook

import urllib #For fetching data from Web URLs

import cv2   #For image processing

from sklearn.preprocessing import LabelEncoder    #For encoding categorical variables
from sklearn.model_selection import train_test_split #For splitting of dataset

#All tensorflow utilities for creating, training and working with a CNN
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, BatchNormalization
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # **After 'X' is downloaded:**

# %%
# some URL images that were not readable were deleted:
X3 = np.load('/content/drive/My Drive/Capstone Project/X_gray_df2598.npy') 
X2 = np.load('/content/drive/My Drive/Capstone Project/X_gray_df2000.npy') 
X1 = np.load('/content/drive/My Drive/Capstone Project/X_gray_df1000.npy') 
X = np.concatenate((X1, X2, X3))
print(X.shape)

#gray image size grayscale 1 color
img_size=(400,300)

#colored image size RGB 3 Colors
#img_size=(400,300,3)
# Out:
# (2598, 120000)

# %% [markdown]
# To see how well the image processing works , we will fetch 5 samples from 'X' at random and plot them:

# %%
#Select 5 processed images at random from 'X' and plot 
for i in range(0, 1):
  plt.figure()
  plt.imshow(X[i].reshape(img_size), cmap='gray'), plt.axis('off')

# %% [markdown]
# **Splitting the data:**
#
# We need to split the data into training, validation, and test sets.
#
# **Creating the Target Array:**
#
# We already have our 'X'. Now, we need our 'Y'.
#
# We will ceate it from the 'Price' column of our dataframe.
#
# if we use brand name column as 'y', It consists of the categorical labels. then We will map each label with a number using the LabelEncoder.

# %%
df= pd.read_csv('/content/drive/My Drive/Capstone Project/df.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ...            shortDescription stockTotal
# 0           0            41  ...   Geranium print mini dress         38
# 1           1            57  ...       Stirrups print blouse         13
# 2           2           122  ...    Zebra print peplum skirt          4
# 3           3           128  ...    Lily print flounce dress         18
# 4           4            96  ...   graffiti art print jacket          1
#
# [5 rows x 20 columns]

# %%
n_classes = df['brand.name'].nunique()
print('Total number of unique categories:', n_classes)
# Out:
# Total number of unique categories: 5

# %%
encoder = LabelEncoder()
Targets = encoder.fit_transform(df['brand.name'])
Targets
Targets.shape
# Out:
# (2598,)

# %%
Y = to_categorical(Targets, num_classes = n_classes)
#Y[0:3]
Y.shape
# Out:
# (2598, 5)

# %% [markdown]
# **Separation of a validation set, and a test set:**

# %%
# we consider 80% of our data as training and 20% as testing:
X_test = X[2000:,]
Y_test = Y[2000:,]

#Seperation of a validation set 15% from the remaing training set (required for validation while training)

X_train, X_val, Y_train, Y_val = train_test_split(X[:2000,], Y[:2000,], test_size=0.15, random_state=13)

# %% [markdown]
# **Reshaping the input data**
#
# we already reshaped out images earlier into 360000x1 row arrays, since it was easier to store them that way. But CNN requires input data in form of nice multi-dimensional grids. For our colored image data, the third dimesion will be 3 and for gray-scale is 1.

# %%
#Reshape the input matrices such that each sample is three-dimensional
#normalizing images between 0 and 1 while splitting the data: X = X/255

img_rows, img_cols = 400, 300
input_shape = (img_rows, img_cols, 1)

X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols, 1)
X_train = X_train/255
X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, 1)
X_test = X_test/255
X_val = X_val.reshape(X_val.shape[0], img_rows, img_cols, 1)
X_val = X_val/255

X_val.shape
# Out:
# (300, 400, 300, 1)

# %% [markdown]
# # **Convolutional Neural Network**
#
# Compiling the model

# %%
#Define a Convolutional Neural Network Model

model = Sequential()

model.add(Conv2D(filters = 16, kernel_size = (3, 3), activation='relu',
                 input_shape = input_shape))
model.add(BatchNormalization())
model.add(Conv2D(filters = 16, kernel_size = (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(strides=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.25))

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(n_classes, activation='softmax'))

learning_rate = 0.001

model.compile(loss = categorical_crossentropy,
              optimizer = Adam(learning_rate),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 398, 298, 16)      160
# _________________________________________________________________
# batch_normalization (BatchNo (None, 398, 298, 16)      64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 396, 296, 16)      2320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 396, 296, 16)      64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 198, 148, 16)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 198, 148, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 196, 146, 32)      4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 196, 146, 32)      128
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 194, 144, 32)      9248
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 194, 144, 32)      128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 97, 72, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 97, 72, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 223488)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               114426368
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 114,973,557
# Trainable params: 114,973,365
# Non-trainable params: 192
# _________________________________________________________________

# %%
#Save the model during training 

save_at = "/content/drive/My Drive/Capstone Project/model.hdf5"
save_best = ModelCheckpoint (save_at, monitor='val_accuracy', verbose=0, save_best_only=True, save_weights_only=False, mode='max')

# %%
#Train the CNN

history = model.fit( X_train, Y_train, 
                    epochs = 100, batch_size = 50, 
                    callbacks=[save_best], verbose=1, 
                    validation_data = (X_val, Y_val))

# Plot the training history (Training accuracy & Validation accuracy)

plt.figure(figsize=(6, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy', weight='bold', fontsize=16)
plt.ylabel('accuracy', weight='bold', fontsize=14)
plt.xlabel('epoch', weight='bold', fontsize=14)
plt.ylim(0.1, 0.9)
plt.xticks(weight='bold', fontsize=12)
plt.yticks(weight='bold', fontsize=12)
plt.legend(['train', 'val'], loc='upper left', prop={'size': 14})
plt.grid(color = 'y', linewidth='0.5')
plt.show()
# Out:
# Epoch 1/100
# 34/34 [==============================] - 265s 8s/step - loss: 1.5619 - accuracy: 0.2735 - val_loss: 87.7741 - val_accuracy: 0.2433
# Epoch 2/100
# 34/34 [==============================] - 267s 8s/step - loss: 1.5610 - accuracy: 0.2694 - val_loss: 16.7970 - val_accuracy: 0.1900
# Epoch 3/100
# 34/34 [==============================] - 265s 8s/step - loss: 1.5685 - accuracy: 0.2635 - val_loss: 6.4183 - val_accuracy: 0.1833
# Epoch 4/100
# 34/34 [==============================] - 266s 8s/step - loss: 1.5544 - accuracy: 0.2541 - val_loss: 3.4828 - val_accuracy: 0.2167
# Epoch 5/100
# 34/34 [==============================] - 267s 8s/step - loss: 1.5529 - accuracy: 0.2747 - val_loss: 3.1323 - val_accuracy: 0.2367
# Epoch 6/100
# 34/34 [==============================] - 272s 8s/step - loss: 1.5499 - accuracy: 0.2753 - val_loss: 3.5772 - val_accuracy: 0.2300
# Epoch 7/100
# 34/34 [==============================] - 266s 8s/step - loss: 1.5575 - accuracy: 0.2606 - val_loss: 12.5322 - val_accuracy: 0.1233
# Epoch 8/100
# 34/34 [==============================] - 292s 9s/step - loss: 1.5527 - accuracy: 0.2600 - val_loss: 7.9092 - val_accuracy: 0.2633
# Epoch 9/100
# 34/34 [==============================] - 291s 9s/step - loss: 1.5605 - accuracy: 0.2582 - val_loss: 14.8906 - val_accuracy: 0.2733
# Epoch 10/100
# 34/34 [==============================] - 267s 8s/step - loss: 1.5943 - accuracy: 0.2594 - val_loss: 5.2209 - val_accuracy: 0.2500
# Epoch 11/100
# 34/34 [==============================] - 264s 8s/step - loss: 1.7165 - accuracy: 0.2588 - val_loss: 174.3315 - val_accuracy: 0.2500
# Epoch 12/100
# 34/34 [==============================] - 267s 8s/step - loss: 1.5601 - accuracy: 0.2718 - val_loss: 380.6696 - val_accuracy: 0.2433
# Epoch 13/100
# 34/34 [==============================] - 266s 8s/step - loss: 1.5543 - accuracy: 0.2571 - val_loss: 368.0760 - val_accuracy: 0.2467
# Epoch 14/100
# 34/34 [==============================] - 265s 8s/step - loss: 1.5560 - accuracy: 0.2518 - val_loss: 256.8666 - val_accuracy: 0.2500
# Epoch 15/100
# 34/34 [==============================] - 268s 8s/step - loss: 1.5521 - accuracy: 0.2476 - val_loss: 74.9199 - val_accuracy: 0.2567
# Epoch 16/100
# 34/34 [==============================] - 267s 8s/step - loss: 1.5623 - accuracy: 0.2576 - val_loss: 143.9335 - val_accuracy: 0.2567
# Epoch 17/100
# 34/34 [==============================] - 267s 8s/step - loss: 1.5716 - accuracy: 0.2547 - val_loss: 6.7194 - val_accuracy: 0.2500
# Epoch 18/100
# 34/34 [==============================] - 262s 8s/step - loss: 1.5533 - accuracy: 0.2418 - val_loss: 7.1420 - val_accuracy: 0.2567
# Epoch 19/100
# 34/34 [==============================] - 287s 8s/step - loss: 1.5563 - accuracy: 0.2588 - val_loss: 47.2300 - val_accuracy: 0.2833
# Epoch 20/100
# 34/34 [==============================] - 292s 9s/step - loss: 1.5611 - accuracy: 0.2665 - val_loss: 51.0951 - val_accuracy: 0.3133
# Epoch 21/100
# 34/34 [==============================] - 267s 8s/step - loss: 1.5543 - accuracy: 0.2482 - val_loss: 43.5853 - val_accuracy: 0.2867
# Epoch 22/100
# 34/34 [==============================] - 289s 9s/step - loss: 1.5539 - accuracy: 0.2582 - val_loss: 36.9847 - val_accuracy: 0.3167
# Epoch 23/100
# 34/34 [==============================] - 270s 8s/step - loss: 1.5534 - accuracy: 0.2641 - val_loss: 32.6156 - val_accuracy: 0.2533
# Epoch 24/100
# 34/34 [==============================] - 267s 8s/step - loss: 1.5538 - accuracy: 0.2641 - val_loss: 29.4861 - val_accuracy: 0.2567
# Epoch 25/100
# 34/34 [==============================] - 265s 8s/step - loss: 1.5563 - accuracy: 0.2447 - val_loss: 27.2065 - val_accuracy: 0.2533
# Epoch 26/100
# 34/34 [==============================] - 266s 8s/step - loss: 1.5547 - accuracy: 0.2612 - val_loss: 25.6374 - val_accuracy: 0.3133
# Epoch 27/100
# 34/34 [==============================] - 261s 8s/step - loss: 1.5530 - accuracy: 0.2594 - val_loss: 24.5255 - val_accuracy: 0.3167
# Epoch 28/100
# 34/34 [==============================] - 262s 8s/step - loss: 1.5547 - accuracy: 0.2576 - val_loss: 23.9298 - val_accuracy: 0.2633
# Epoch 29/100
# 34/34 [==============================] - 262s 8s/step - loss: 1.5550 - accuracy: 0.2706 - val_loss: 23.4275 - val_accuracy: 0.2567
# Epoch 30/100
# 34/34 [==============================] - 262s 8s/step - loss: 1.5543 - accuracy: 0.2700 - val_loss: 23.0638 - val_accuracy: 0.2567
# Epoch 31/100
# 34/34 [==============================] - 263s 8s/step - loss: 1.5537 - accuracy: 0.2641 - val_loss: 22.7552 - val_accuracy: 0.2667
# Epoch 32/100
# 34/34 [==============================] - 264s 8s/step - loss: 1.5544 - accuracy: 0.2594 - val_loss: 22.6577 - val_accuracy: 0.2667
# Epoch 33/100
# 34/34 [==============================] - 268s 8s/step - loss: 1.5553 - accuracy: 0.2406 - val_loss: 22.4804 - val_accuracy: 0.2567
# Epoch 34/100
# 34/34 [==============================] - 265s 8s/step - loss: 1.5537 - accuracy: 0.2559 - val_loss: 22.3233 - val_accuracy: 0.2567
# Epoch 35/100
# 34/34 [==============================] - 267s 8s/step - loss: 1.5537 - accuracy: 0.2641 - val_loss: 22.2627 - val_accuracy: 0.3067
# Epoch 36/100
# 34/34 [==============================] - 261s 8s/step - loss: 1.5540 - accuracy: 0.2465 - val_loss: 22.2917 - val_accuracy: 0.2633
# Epoch 37/100
# 34/34 [==============================] - 266s 8s/step - loss: 1.5538 - accuracy: 0.2588 - val_loss: 22.2874 - val_accuracy: 0.3100
# Epoch 38/100
# 34/34 [==============================] - 264s 8s/step - loss: 1.5554 - accuracy: 0.2618 - val_loss: 22.3055 - val_accuracy: 0.3100
# Epoch 39/100
# 34/34 [==============================] - 264s 8s/step - loss: 1.5552 - accuracy: 0.2612 - val_loss: 22.4410 - val_accuracy: 0.2600
# Epoch 40/100
# 34/34 [==============================] - 264s 8s/step - loss: 1.5531 - accuracy: 0.2600 - val_loss: 22.3179 - val_accuracy: 0.2600
# Epoch 41/100
# 34/34 [==============================] - 265s 8s/step - loss: 1.5543 - accuracy: 0.2588 - val_loss: 22.2976 - val_accuracy: 0.2633
# Epoch 42/100
# 34/34 [==============================] - 265s 8s/step - loss: 1.5551 - accuracy: 0.2559 - val_loss: 22.2825 - val_accuracy: 0.2633
# Epoch 43/100
# 34/34 [==============================] - 264s 8s/step - loss: 1.5553 - accuracy: 0.2647 - val_loss: 22.2699 - val_accuracy: 0.3100
# Epoch 44/100
# 34/34 [==============================] - 266s 8s/step - loss: 1.5534 - accuracy: 0.2612 - val_loss: 22.2796 - val_accuracy: 0.2600
# Epoch 45/100
# 34/34 [==============================] - 260s 8s/step - loss: 1.5552 - accuracy: 0.2535 - val_loss: 22.3021 - val_accuracy: 0.2633
# Epoch 46/100
# 34/34 [==============================] - 262s 8s/step - loss: 1.5548 - accuracy: 0.2418 - val_loss: 22.2137 - val_accuracy: 0.3100
# Epoch 47/100
# 34/34 [==============================] - 261s 8s/step - loss: 1.5549 - accuracy: 0.2571 - val_loss: 22.2724 - val_accuracy: 0.3100
# Epoch 48/100
# 34/34 [==============================] - 262s 8s/step - loss: 1.5551 - accuracy: 0.2500 - val_loss: 22.1917 - val_accuracy: 0.3167
# Epoch 49/100
# 34/34 [==============================] - 265s 8s/step - loss: 1.5545 - accuracy: 0.2647 - val_loss: 22.1842 - val_accuracy: 0.2667
# Epoch 50/100
# 34/34 [==============================] - 265s 8s/step - loss: 1.5535 - accuracy: 0.2565 - val_loss: 22.1874 - val_accuracy: 0.3100
# Epoch 51/100
# 34/34 [==============================] - 266s 8s/step - loss: 1.5541 - accuracy: 0.2647 - val_loss: 22.1038 - val_accuracy: 0.2667
# Epoch 52/100
# 34/34 [==============================] - 265s 8s/step - loss: 1.5551 - accuracy: 0.2465 - val_loss: 22.1567 - val_accuracy: 0.2667
# Epoch 53/100
# 34/34 [==============================] - 264s 8s/step - loss: 1.5548 - accuracy: 0.2782 - val_loss: 22.1519 - val_accuracy: 0.3100
# Epoch 54/100
# 34/34 [==============================] - 260s 8s/step - loss: 1.5548 - accuracy: 0.2524 - val_loss: 22.1592 - val_accuracy: 0.3100
# Epoch 55/100
# 34/34 [==============================] - 259s 8s/step - loss: 1.5551 - accuracy: 0.2471 - val_loss: 22.1918 - val_accuracy: 0.2667
# Epoch 56/100
# 34/34 [==============================] - 259s 8s/step - loss: 1.5541 - accuracy: 0.2565 - val_loss: 22.2296 - val_accuracy: 0.2633
# Epoch 57/100
# 34/34 [==============================] - 259s 8s/step - loss: 1.5541 - accuracy: 0.2459 - val_loss: 22.2118 - val_accuracy: 0.2667
# Epoch 58/100
# 34/34 [==============================] - 259s 8s/step - loss: 1.5541 - accuracy: 0.2700 - val_loss: 22.1077 - val_accuracy: 0.2667
# Epoch 59/100
# 34/34 [==============================] - 262s 8s/step - loss: 1.5531 - accuracy: 0.2747 - val_loss: 22.1456 - val_accuracy: 0.3133
# Epoch 60/100
# 34/34 [==============================] - 259s 8s/step - loss: 1.5543 - accuracy: 0.2524 - val_loss: 22.1612 - val_accuracy: 0.3133
# Epoch 61/100
# 34/34 [==============================] - 259s 8s/step - loss: 1.5531 - accuracy: 0.2724 - val_loss: 22.1180 - val_accuracy: 0.3100
# Epoch 62/100
# 34/34 [==============================] - 262s 8s/step - loss: 1.5540 - accuracy: 0.2506 - val_loss: 22.2262 - val_accuracy: 0.2667
# Epoch 63/100
# 34/34 [==============================] - 261s 8s/step - loss: 1.5547 - accuracy: 0.2547 - val_loss: 22.1741 - val_accuracy: 0.2667
# Epoch 64/100
# 34/34 [==============================] - 260s 8s/step - loss: 1.5539 - accuracy: 0.2653 - val_loss: 22.2036 - val_accuracy: 0.2667
# Epoch 65/100
# 34/34 [==============================] - 260s 8s/step - loss: 1.5535 - accuracy: 0.2700 - val_loss: 22.1934 - val_accuracy: 0.3133
# Epoch 66/100
# 34/34 [==============================] - 261s 8s/step - loss: 1.5533 - accuracy: 0.2612 - val_loss: 22.1959 - val_accuracy: 0.2600
# Epoch 67/100
# 34/34 [==============================] - 263s 8s/step - loss: 1.5542 - accuracy: 0.2582 - val_loss: 22.2058 - val_accuracy: 0.2600
# Epoch 68/100
# 34/34 [==============================] - 263s 8s/step - loss: 1.5551 - accuracy: 0.2624 - val_loss: 22.1557 - val_accuracy: 0.2600
# Epoch 69/100
# 34/34 [==============================] - 266s 8s/step - loss: 1.5543 - accuracy: 0.2518 - val_loss: 22.1771 - val_accuracy: 0.2633
# Epoch 70/100
# 34/34 [==============================] - 263s 8s/step - loss: 1.5538 - accuracy: 0.2500 - val_loss: 22.2345 - val_accuracy: 0.2667
# Epoch 71/100
# 34/34 [==============================] - 261s 8s/step - loss: 1.5543 - accuracy: 0.2659 - val_loss: 22.1705 - val_accuracy: 0.3133
# Epoch 72/100
# 34/34 [==============================] - 262s 8s/step - loss: 1.5547 - accuracy: 0.2600 - val_loss: 22.1671 - val_accuracy: 0.3167
# Epoch 73/100
# 34/34 [==============================] - 264s 8s/step - loss: 1.5532 - accuracy: 0.2676 - val_loss: 22.2060 - val_accuracy: 0.2667
# Epoch 74/100
# 34/34 [==============================] - 263s 8s/step - loss: 1.5543 - accuracy: 0.2612 - val_loss: 22.2043 - val_accuracy: 0.2667
# Epoch 75/100
# 34/34 [==============================] - 266s 8s/step - loss: 1.5538 - accuracy: 0.2735 - val_loss: 22.2719 - val_accuracy: 0.2633
# Epoch 76/100
# 34/34 [==============================] - 267s 8s/step - loss: 1.5550 - accuracy: 0.2665 - val_loss: 22.2509 - val_accuracy: 0.3100
# Epoch 77/100
# 34/34 [==============================] - 266s 8s/step - loss: 1.5546 - accuracy: 0.2494 - val_loss: 22.3599 - val_accuracy: 0.2633
# Epoch 78/100
# 34/34 [==============================] - 265s 8s/step - loss: 1.5531 - accuracy: 0.2635 - val_loss: 22.3027 - val_accuracy: 0.3167
# Epoch 79/100
# 34/34 [==============================] - 262s 8s/step - loss: 1.5541 - accuracy: 0.2612 - val_loss: 22.3553 - val_accuracy: 0.2700
# Epoch 80/100
# 34/34 [==============================] - 262s 8s/step - loss: 1.5552 - accuracy: 0.2459 - val_loss: 22.2947 - val_accuracy: 0.3167
# Epoch 81/100
# 34/34 [==============================] - 263s 8s/step - loss: 1.5551 - accuracy: 0.2541 - val_loss: 22.2877 - val_accuracy: 0.3167
# Epoch 82/100
# 34/34 [==============================] - 263s 8s/step - loss: 1.5539 - accuracy: 0.2818 - val_loss: 22.3052 - val_accuracy: 0.2667
# Epoch 83/100
# 34/34 [==============================] - 262s 8s/step - loss: 1.5550 - accuracy: 0.2453 - val_loss: 22.1847 - val_accuracy: 0.3167
# Epoch 84/100
# 34/34 [==============================] - 263s 8s/step - loss: 1.5543 - accuracy: 0.2529 - val_loss: 22.2049 - val_accuracy: 0.2667
# Epoch 85/100
# 34/34 [==============================] - 264s 8s/step - loss: 1.5542 - accuracy: 0.2629 - val_loss: 22.2540 - val_accuracy: 0.2700
# Epoch 86/100
# 34/34 [==============================] - 287s 8s/step - loss: 1.5536 - accuracy: 0.2706 - val_loss: 22.1020 - val_accuracy: 0.3200
# Epoch 87/100
# 34/34 [==============================] - 269s 8s/step - loss: 1.5541 - accuracy: 0.2612 - val_loss: 22.1875 - val_accuracy: 0.2700
# Epoch 88/100
# 34/34 [==============================] - 289s 8s/step - loss: 1.5547 - accuracy: 0.2612 - val_loss: 22.0842 - val_accuracy: 0.3233
# Epoch 89/100
# 34/34 [==============================] - 268s 8s/step - loss: 1.5546 - accuracy: 0.2606 - val_loss: 22.1064 - val_accuracy: 0.2633
# Epoch 90/100
# 34/34 [==============================] - 263s 8s/step - loss: 1.5551 - accuracy: 0.2518 - val_loss: 22.0470 - val_accuracy: 0.2733
# Epoch 91/100
# 34/34 [==============================] - 263s 8s/step - loss: 1.5537 - accuracy: 0.2576 - val_loss: 22.1269 - val_accuracy: 0.2700
# Epoch 92/100
# 34/34 [==============================] - 289s 8s/step - loss: 1.5547 - accuracy: 0.2547 - val_loss: 22.0171 - val_accuracy: 0.3267
# Epoch 93/100
# 34/34 [==============================] - 269s 8s/step - loss: 1.5542 - accuracy: 0.2565 - val_loss: 21.9032 - val_accuracy: 0.2767
# Epoch 94/100
# 34/34 [==============================] - 265s 8s/step - loss: 1.5540 - accuracy: 0.2618 - val_loss: 22.0922 - val_accuracy: 0.2700
# Epoch 95/100
# 34/34 [==============================] - 263s 8s/step - loss: 1.5539 - accuracy: 0.2606 - val_loss: 22.1065 - val_accuracy: 0.2733
# Epoch 96/100
# 34/34 [==============================] - 264s 8s/step - loss: 1.5550 - accuracy: 0.2482 - val_loss: 22.0427 - val_accuracy: 0.2767
# Epoch 97/100
# 34/34 [==============================] - 260s 8s/step - loss: 1.5557 - accuracy: 0.2529 - val_loss: 21.9680 - val_accuracy: 0.2767
# Epoch 98/100
# 34/34 [==============================] - 260s 8s/step - loss: 1.5539 - accuracy: 0.2653 - val_loss: 22.0007 - val_accuracy: 0.2733
# Epoch 99/100
# 34/34 [==============================] - 261s 8s/step - loss: 1.5536 - accuracy: 0.2594 - val_loss: 21.8552 - val_accuracy: 0.2733
# Epoch 100/100
# 34/34 [==============================] - 261s 8s/step - loss: 1.5543 - accuracy: 0.2700 - val_loss: 21.9070 - val_accuracy: 0.3267

# %% [markdown]
# The accuracy of the model is not satisfying so we are going to try other activation function or layers to explore the results.
