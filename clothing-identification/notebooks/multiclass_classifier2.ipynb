# %% [markdown]
# <a href="https://colab.research.google.com/github/FarnazG/dsc-capstone-project-v2-online-ds-ft-120919/blob/master/multiclass_classifier2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  **Modeling:**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras import losses

import numpy as np #for numerical computations
import pandas as pd #for dataframe operations

from matplotlib import pyplot as plt #for viewing images and plots
# %matplotlib inline 
#So that Matplotlib plots don't open in separate windows outside the notebook

import urllib #For fetching data from Web URLs

import cv2   #For image processing

from sklearn.preprocessing import LabelEncoder    #For encoding categorical variables
from sklearn.model_selection import train_test_split #For splitting of dataset

#All tensorflow utilities for creating, training and working with a CNN
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, BatchNormalization
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model

# %% [markdown]
# # **After 'X' is downloaded:**

# %%
# some URL images that were not readable were deleted:
X3 = np.load('/content/drive/My Drive/Capstone Project/X_gray_df2598.npy') 
X2 = np.load('/content/drive/My Drive/Capstone Project/X_gray_df2000.npy') 
X1 = np.load('/content/drive/My Drive/Capstone Project/X_gray_df1000.npy') 
X = np.concatenate((X1, X2, X3))
print(X.shape)

#gray image size grayscale 1 color
img_size=(400,300)

#colored image size RGB 3 Colors
#img_size=(400,300,3)
# Out:
# (2598, 120000)

# %% [markdown]
# To see how well the image processing works , we will fetch 5 samples from 'X' at random and plot them:

# %%
#Select 5 processed images at random from 'X' and plot 
for i in range(0, 1):
  plt.figure()
  plt.imshow(X[i].reshape(img_size), cmap='gray'), plt.axis('off')

# %% [markdown]
# **Splitting the data:**
#
# We need to split the data into training, validation, and test sets.
#
# **Creating the Target Array:**
#
# We already have our 'X'. Now, we need our 'Y'.
#
# We will ceate it from the 'Price' column of our dataframe.
#
# if we use brand name column as 'y', It consists of the categorical labels. then We will map each label with a number using the LabelEncoder.

# %%
df= pd.read_csv('/content/drive/My Drive/Capstone Project/df.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ...            shortDescription stockTotal
# 0           0            41  ...   Geranium print mini dress         38
# 1           1            57  ...       Stirrups print blouse         13
# 2           2           122  ...    Zebra print peplum skirt          4
# 3           3           128  ...    Lily print flounce dress         18
# 4           4            96  ...   graffiti art print jacket          1
#
# [5 rows x 20 columns]

# %%
n_classes = df['brand.name'].nunique()
print('Total number of unique categories:', n_classes)
# Out:
# Total number of unique categories: 5

# %%
encoder = LabelEncoder()
Targets = encoder.fit_transform(df['brand.name'])
Targets
Targets.shape
# Out:
# (2598,)

# %%
Y = to_categorical(Targets, num_classes = n_classes)
#Y[0:3]
Y.shape
# Out:
# (2598, 5)

# %% [markdown]
# **Separation of a validation set, and a test set:**

# %%
# we consider 80% of our data as training and 20% as testing:
X_test = X[2000:,]
Y_test = Y[2000:,]

#Seperation of a validation set 15% from the remaing training set (required for validation while training)

X_train, X_val, Y_train, Y_val = train_test_split(X[:2000,], Y[:2000,], test_size=0.15, random_state=13)

# %% [markdown]
# **Reshaping the input data**
#
# we already reshaped out images earlier into 360000x1 row arrays, since it was easier to store them that way. But CNN requires input data in form of nice multi-dimensional grids. For our colored image data, the third dimesion will be 3 and for gray-scale is 1.

# %%
#Reshape the input matrices such that each sample is three-dimensional
#normalizing images between 0 and 1 while splitting the data: X = X/255

img_rows, img_cols = 400, 300
input_shape = (img_rows, img_cols, 1)

X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols, 1)
X_train = X_train/255
X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, 1)
X_test = X_test/255
X_val = X_val.reshape(X_val.shape[0], img_rows, img_cols, 1)
X_val = X_val/255

X_val.shape
# Out:
# (300, 400, 300, 1)

# %% [markdown]
# # **Convolutional Neural Network**
#
# Compiling the model

# %%
#Define a Convolutional Neural Network Model
#Changing the activation function from Relu to tanh, decreasing the number of layers

model = Sequential()

model.add(Conv2D(filters = 16, kernel_size = (3, 3), activation='tanh',
                 input_shape = input_shape))
model.add(BatchNormalization())
model.add(Conv2D(filters = 16, kernel_size = (3, 3), activation='tanh'))
model.add(BatchNormalization())
model.add(MaxPool2D(strides=(2,2)))
model.add(Dropout(0.25))

# model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation='relu'))
# model.add(BatchNormalization())
# model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation='relu'))
# model.add(BatchNormalization())
# model.add(MaxPool2D(strides=(2,2)))
# model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.25))

model.add(Dense(1024, activation='tanh'))
model.add(Dropout(0.4))
model.add(Dense(n_classes, activation='softmax'))

learning_rate = 0.001

model.compile(loss = categorical_crossentropy,
              optimizer = Adam(learning_rate),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 398, 298, 16)      160
# _________________________________________________________________
# batch_normalization (BatchNo (None, 398, 298, 16)      64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 396, 296, 16)      2320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 396, 296, 16)      64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 198, 148, 16)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 198, 148, 16)      0
# _________________________________________________________________
# flatten (Flatten)            (None, 468864)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               240058880
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 240,591,925
# Trainable params: 240,591,861
# Non-trainable params: 64
# _________________________________________________________________

# %%
#Save the model during training 

save_at = "/content/drive/My Drive/Capstone Project/model.hdf5"
save_best = ModelCheckpoint (save_at, monitor='val_accuracy', verbose=0, save_best_only=True, save_weights_only=False, mode='max')

# %%
#Train the CNN

history = model.fit( X_train, Y_train, 
                    epochs = 40, batch_size = 50, 
                    callbacks=[save_best], verbose=1, 
                    validation_data = (X_val, Y_val))

# Plot the training history (Training accuracy & Validation accuracy)

plt.figure(figsize=(6, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy', weight='bold', fontsize=16)
plt.ylabel('accuracy', weight='bold', fontsize=14)
plt.xlabel('epoch', weight='bold', fontsize=14)
plt.ylim(0.1, 0.9)
plt.xticks(weight='bold', fontsize=12)
plt.yticks(weight='bold', fontsize=12)
plt.legend(['train', 'val'], loc='upper left', prop={'size': 14})
plt.grid(color = 'y', linewidth='0.5')
plt.show()
# Out:
# Epoch 1/40
# 34/34 [==============================] - 284s 8s/step - loss: 1.7656 - accuracy: 0.2900 - val_loss: 1.6485 - val_accuracy: 0.3167
# Epoch 2/40
# 34/34 [==============================] - 297s 9s/step - loss: 1.7123 - accuracy: 0.2959 - val_loss: 1.5647 - val_accuracy: 0.3367
# Epoch 3/40
# 34/34 [==============================] - 224s 7s/step - loss: 1.7185 - accuracy: 0.2988 - val_loss: 1.6992 - val_accuracy: 0.3300
# Epoch 4/40
# 34/34 [==============================] - 219s 6s/step - loss: 1.7228 - accuracy: 0.2888 - val_loss: 1.6256 - val_accuracy: 0.3167
# Epoch 5/40
# 34/34 [==============================] - 217s 6s/step - loss: 1.7083 - accuracy: 0.2900 - val_loss: 1.6103 - val_accuracy: 0.3233
# Epoch 6/40
# 34/34 [==============================] - 216s 6s/step - loss: 1.6694 - accuracy: 0.2994 - val_loss: 1.6029 - val_accuracy: 0.3267
# Epoch 7/40
# 34/34 [==============================] - 214s 6s/step - loss: 1.6275 - accuracy: 0.3059 - val_loss: 1.5792 - val_accuracy: 0.2933
# Epoch 8/40
# 34/34 [==============================] - 216s 6s/step - loss: 1.6600 - accuracy: 0.2929 - val_loss: 1.9517 - val_accuracy: 0.2467
# Epoch 9/40
# 34/34 [==============================] - 214s 6s/step - loss: 1.6392 - accuracy: 0.2947 - val_loss: 2.4008 - val_accuracy: 0.1600
# Epoch 10/40
# 34/34 [==============================] - 216s 6s/step - loss: 1.6467 - accuracy: 0.2976 - val_loss: 1.6867 - val_accuracy: 0.2533
# Epoch 11/40
# 34/34 [==============================] - 215s 6s/step - loss: 1.6429 - accuracy: 0.2976 - val_loss: 1.6744 - val_accuracy: 0.2900
# Epoch 12/40
# 34/34 [==============================] - 211s 6s/step - loss: 1.6185 - accuracy: 0.3082 - val_loss: 1.7134 - val_accuracy: 0.2767
# Epoch 13/40
# 34/34 [==============================] - 213s 6s/step - loss: 1.6263 - accuracy: 0.2994 - val_loss: 1.6048 - val_accuracy: 0.2767
# Epoch 14/40
# 34/34 [==============================] - 212s 6s/step - loss: 1.6106 - accuracy: 0.2965 - val_loss: 1.5557 - val_accuracy: 0.3367
# Epoch 15/40
# 34/34 [==============================] - 212s 6s/step - loss: 1.5866 - accuracy: 0.3000 - val_loss: 1.7065 - val_accuracy: 0.2433
# Epoch 16/40
# 34/34 [==============================] - 214s 6s/step - loss: 1.5738 - accuracy: 0.3182 - val_loss: 1.6789 - val_accuracy: 0.2600
# Epoch 17/40
# 34/34 [==============================] - 220s 6s/step - loss: 1.5837 - accuracy: 0.3076 - val_loss: 1.5974 - val_accuracy: 0.2733
# Epoch 18/40
# 34/34 [==============================] - 209s 6s/step - loss: 1.5668 - accuracy: 0.3006 - val_loss: 1.5836 - val_accuracy: 0.2933
# Epoch 19/40
# 34/34 [==============================] - 210s 6s/step - loss: 1.5856 - accuracy: 0.2982 - val_loss: 1.5537 - val_accuracy: 0.3167
# Epoch 20/40
# 34/34 [==============================] - 212s 6s/step - loss: 1.5517 - accuracy: 0.3153 - val_loss: 1.5701 - val_accuracy: 0.2833
# Epoch 21/40
# 34/34 [==============================] - 221s 7s/step - loss: 1.5615 - accuracy: 0.3176 - val_loss: 1.5454 - val_accuracy: 0.3333
# Epoch 22/40
# 34/34 [==============================] - 208s 6s/step - loss: 1.5402 - accuracy: 0.3206 - val_loss: 1.5704 - val_accuracy: 0.3100
# Epoch 23/40
# 34/34 [==============================] - 210s 6s/step - loss: 1.5756 - accuracy: 0.2988 - val_loss: 1.5667 - val_accuracy: 0.3233
# Epoch 24/40
# 34/34 [==============================] - 209s 6s/step - loss: 1.5434 - accuracy: 0.3141 - val_loss: 1.6057 - val_accuracy: 0.2967
# Epoch 25/40
# 34/34 [==============================] - 211s 6s/step - loss: 1.5499 - accuracy: 0.3035 - val_loss: 1.5589 - val_accuracy: 0.2867
# Epoch 26/40
# 34/34 [==============================] - 211s 6s/step - loss: 1.5297 - accuracy: 0.3053 - val_loss: 1.5864 - val_accuracy: 0.3200
# Epoch 27/40
# 34/34 [==============================] - 214s 6s/step - loss: 1.5606 - accuracy: 0.3118 - val_loss: 1.5899 - val_accuracy: 0.3300
# Epoch 28/40
# 34/34 [==============================] - 217s 6s/step - loss: 1.5283 - accuracy: 0.3141 - val_loss: 1.5665 - val_accuracy: 0.2900
# Epoch 29/40
# 34/34 [==============================] - 216s 6s/step - loss: 1.5304 - accuracy: 0.3188 - val_loss: 1.6789 - val_accuracy: 0.2433
# Epoch 30/40
# 34/34 [==============================] - 217s 6s/step - loss: 1.5365 - accuracy: 0.3241 - val_loss: 1.7991 - val_accuracy: 0.2233
# Epoch 31/40
# 34/34 [==============================] - 210s 6s/step - loss: 1.5253 - accuracy: 0.3247 - val_loss: 1.5959 - val_accuracy: 0.3000
# Epoch 32/40
# 34/34 [==============================] - 207s 6s/step - loss: 1.5406 - accuracy: 0.3271 - val_loss: 1.5541 - val_accuracy: 0.3233
# Epoch 33/40
# 34/34 [==============================] - 209s 6s/step - loss: 1.4987 - accuracy: 0.3447 - val_loss: 1.6064 - val_accuracy: 0.3033
# Epoch 34/40
# 34/34 [==============================] - 210s 6s/step - loss: 1.5265 - accuracy: 0.3341 - val_loss: 1.5916 - val_accuracy: 0.2667
# Epoch 35/40
# 34/34 [==============================] - 209s 6s/step - loss: 1.5182 - accuracy: 0.3253 - val_loss: 1.5511 - val_accuracy: 0.3333
# Epoch 36/40
# 34/34 [==============================] - 211s 6s/step - loss: 1.5258 - accuracy: 0.3129 - val_loss: 1.5818 - val_accuracy: 0.2833
# Epoch 37/40
# 34/34 [==============================] - 211s 6s/step - loss: 1.5272 - accuracy: 0.3141 - val_loss: 1.7174 - val_accuracy: 0.2000
# Epoch 38/40
# 34/34 [==============================] - 214s 6s/step - loss: 1.4958 - accuracy: 0.3282 - val_loss: 1.5107 - val_accuracy: 0.3300
# Epoch 39/40
# 34/34 [==============================] - 214s 6s/step - loss: 1.5223 - accuracy: 0.3265 - val_loss: 1.6198 - val_accuracy: 0.3033
# Epoch 40/40
# 34/34 [==============================] - 215s 6s/step - loss: 1.5316 - accuracy: 0.3235 - val_loss: 1.6618 - val_accuracy: 0.2933

# %% [markdown]
# The accuracy of the model is still not satisfying, so we are going to make more changes to the model architecture.
